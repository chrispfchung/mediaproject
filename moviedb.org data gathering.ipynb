# %%
import requests
import json
key = '52aab80dea7e8b6ea52275d87da6b430'
response = requests.get(f'https://api.themoviedb.org/3/search/movie/?api_key={key}&query=Jack+Reacher')
response.text
# Out:
# '{"page":1,"total_results":2,"total_pages":1,"results":[{"popularity":22.424,"id":75780,"video":false,"vote_count":4507,"vote_average":6.5,"title":"Jack Reacher","release_date":"2012-12-20","original_language":"en","original_title":"Jack Reacher","genre_ids":[80,18,53,28],"backdrop_path":"\\/ezXodpP429qK0Av89pVNlaXWJkQ.jpg","adult":false,"overview":"When a gunman takes five lives with six shots, all evidence points to the suspect in custody. On interrogation, the suspect offers up a single note: \\"Get Jack Reacher!\\" So begins an extraordinary chase for the truth, pitting Jack Reacher against an unexpected enemy, with a skill for violence and a secret to keep.","poster_path":"\\/mt0ELw83HIRgaKaDzhsDcIi0RnW.jpg"},{"popularity":22.024,"vote_count":3048,"video":false,"poster_path":"\\/IfB9hy4JH1eH6HEfIgIGORXi5h.jpg","id":343611,"adult":false,"backdrop_path":"\\/nDS8rddEK74HfAwCC5CoT6Cwzlt.jpg","original_language":"en","original_title":"Jack Reacher: Never Go Back","genre_ids":[28,53],"title":"Jack Reacher: Never Go Back","vote_average":5.6,"overview":"Jack Reacher must uncover the truth behind a major government conspiracy in order to clear his name. On the run as a fugitive from the law, Reacher uncovers a potential secret from his past that could change his life forever.","release_date":"2016-10-19"}]}'

# %%
# get top rated (get all of the movie ids)
# get details  (use the ids to plug into this api)
# plug all necessary data into a csv

# get all genre codes (https://developers.themoviedb.org/3/genres/get-movie-list)

# %%
response = requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=52aab80dea7e8b6ea52275d87da6b430&language=en-US&page=1')
results_test = []
result_pages = response.json()['results']
ids = [page['id'] for page in result_pages]
# Out:
# int

# %%
response = requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=52aab80dea7e8b6ea52275d87da6b430&language=en-US&page=1')
pages = [i for i in range(1, response.json()['total_pages']+1)]
all_ids =[]
for i in pages:
    get = requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=52aab80dea7e8b6ea52275d87da6b430&language=en-US&page={i}')
    result_movies = get.json()['results']
    for movie in result_movies:
        all_ids.append(movie['id'])
# Out:
# [19404,
#  278,
#  238,
#  496243,
#  424,
#  240,
#  372058,
#  129,
#  497,
#  680,
#  637,
#  13,
#  155,
#  122,
#  346,
#  311,
#  769,
#  40096,
#  539,
#  389,
#  429,
#  510,
#  550,
#  324857,
#  11216,
#  598,
#  579245,
#  244786,
#  901,
#  599,
#  12477,
#  18491,
#  73,
#  914,
#  432517,
#  1891,
#  3782,
#  4935,
#  18148,
#  128,
#  11659,
#  508965,
#  313106,
#  567,
#  452522,
#  975,
#  14537,
#  207,
#  265177,
#  423,
#  10376,
#  797,
#  12493,
#  20914,
#  26451,
#  120,
#  3082,
#  101,
#  25237,
#  807,
#  531428,
#  27205,
#  290098,
#  895,
#  24188,
#  274,
#  121,
#  335,
#  37257,
#  299534,
#  1398,
#  24382,
#  490132,
#  517814,
#  455661,
#  398818,
#  157336,
#  470044,
#  422,
#  299536,
#  446159,
#  28,
#  378064,
#  8587,
#  105,
#  284,
#  10098,
#  5156,
#  475557,
#  426,
#  992,
#  77338,
#  670,
#  1585,
#  705,
#  110420,
#  490,
#  629,
#  19,
#  11,
#  185,
#  406997,
#  538362,
#  354912,
#  694,
#  586863,
#  437068,
#  38288,
#  77,
#  10494,
#  11878,
#  996,
#  548,
#  103,
#  411088,
#  239,
#  339877,
#  780,
#  614,
#  429210,
#  19542,
#  1124,
#  1396,
#  399106,
#  872,
#  500,
#  439,
#  935,
#  14696,
#  16869,
#  359940,
#  147,
#  28978,
#  334543,
#  98,
#  282848,
#  832,
#  1422,
#  100,
#  50014,
#  515001,
#  149871,
#  111,
#  11645,
#  833,
#  92321,
#  92060,
#  11324,
#  961,
#  8392,
#  289,
#  160885,
#  449176,
#  1059,
#  857,
#  264644,
#  11712,
#  603,
#  110416,
#  237791,
#  19426,
#  655,
#  600,
#  7345,
#  654,
#  378108,
#  11423,
#  10242,
#  18438,
#  489,
#  843,
#  12445,
#  527641,
#  3090,
#  46738,
#  666,
#  1955,
#  324786,
#  42229,
#  307,
#  348,
#  387,
#  310569,
#  11104,
#  38,
#  582,
#  498249,
#  1394,
#  68718,
#  15,
#  110,
#  204,
#  821,
#  205596,
#  62,
#  7347,
#  8422,
#  9277,
#  37165,
#  103663,
#  140420,
#  406,
#  32085,
#  662,
#  29264,
#  595,
#  1092,
#  3083,
#  360814,
#  120467,
#  12104,
#  15383,
#  15244,
#  28971,
#  14,
#  11778,
#  641,
#  530915,
#  10997,
#  1580,
#  3777,
#  17295,
#  10404,
#  3175,
#  38286,
#  393729,
#  424694,
#  279,
#  938,
#  521,
#  491480,
#  962,
#  7508,
#  24167,
#  381284,
#  146233,
#  414419,
#  28178,
#  315465,
#  775,
#  505192,
#  7857,
#  1892,
#  10681,
#  213,
#  430424,
#  3112,
#  1091,
#  524,
#  10238,
#  631,
#  405,
#  41050,
#  31442,
#  334533,
#  11656,
#  947,
#  5925,
#  21334,
#  106646,
#  10515,
#  316029,
#  331482,
#  83564,
#  1626,
#  369557,
#  60243,
#  25364,
#  280,
#  13223,
#  627,
#  1578,
#  293299,
#  11010,
#  185789,
#  673,
#  379170,
#  20722,
#  5924,
#  24,
#  20453,
#  25376,
#  76203,
#  33320,
#  152532,
#  142061,
#  113833,
#  5511,
#  5544,
#  223,
#  1675,
#  16,
#  381341,
#  829,
#  150540,
#  3034,
#  862,
#  70,
#  78,
#  492188,
#  505262,
#  149,
#  2011,
#  827,
#  934,
#  11293,
#  11953,
#  33,
#  9323,
#  337960,
#  301,
#  804,
#  336804,
#  10774,
#  266856,
#  76,
#  4348,
#  234,
#  93,
#  118340,
#  593,
#  400928,
#  396,
#  31011,
#  522627,
#  7984,
#  25606,
#  745,
#  359156,
#  640,
#  451945,
#  198,
#  8290,
#  14160,
#  81,
#  20334,
#  596,
#  194,
#  770,
#  348892,
#  32480,
#  11602,
#  6977,
#  20126,
#  398924,
#  1402,
#  10674,
#  3078,
#  210577,
#  197,
#  391,
#  435129,
#  235,
#  752,
#  115,
#  27670,
#  85,
#  144,
#  21634,
#  303,
#  826,
#  329,
#  679,
#  851,
#  313369,
#  13042,
#  152601,
#  8327,
#  242828,
#  399174,
#  275,
#  234200,
#  16804,
#  37797,
#  575452,
#  11036,
#  152742,
#  113,
#  122906,
#  24238,
#  696,
#  5961,
#  10227,
#  169813,
#  777,
#  949,
#  671,
#  393,
#  13398,
#  990,
#  71157,
#  887,
#  499,
#  13929,
#  5915,
#  453,
#  466282,
#  25253,
#  925,
#  14574,
#  314365,
#  963,
#  24480,
#  702,
#  581,
#  10386,
#  1018,
#  762,
#  6075,
#  703,
#  141,
#  203217,
#  597,
#  613,
#  1280,
#  13855,
#  393559,
#  8416,
#  12093,
#  2108,
#  3870,
#  49687,
#  9479,
#  16859,
#  1480,
#  9421,
#  382591,
#  1646,
#  33602,
#  24657,
#  968,
#  336,
#  335578,
#  873,
#  12,
#  200727,
#  546554,
#  265195,
#  108,
#  1628,
#  776,
#  371645,
#  845,
#  336808,
#  553,
#  14069,
#  110160,
#  3114,
#  981,
#  11787,
#  143,
#  632,
#  10775,
#  238628,
#  583,
#  805,
#  320007,
#  136,
#  269,
#  14580,
#  263115,
#  903,
#  29458,
#  11005,
#  4977,
#  137182,
#  16305,
#  404,
#  398978,
#  359724,
#  2440,
#  10633,
#  26022,
#  982,
#  4480,
#  142,
#  585,
#  89,
#  107,
#  2118,
#  59440,
#  11220,
#  297222,
#  261,
#  488623,
#  10835,
#  80,
#  149870,
#  891,
#  11902,
#  25188,
#  52345,
#  674,
#  10193,
#  164,
#  11621,
#  24653,
#  177572,
#  265169,
#  86837,
#  1075,
#  22843,
#  587,
#  117,
#  30018,
#  1093,
#  12444,
#  428493,
#  309,
#  47931,
#  995,
#  49797,
#  11686,
#  380,
#  11898,
#  665,
#  678,
#  126319,
#  10191,
#  568160,
#  9800,
#  506574,
#  13386,
#  10020,
#  28580,
#  18329,
#  12405,
#  4808,
#  269149,
#  247,
#  12548,
#  426426,
#  525,
#  14811,
#  11697,
#  484751,
#  16391,
#  322,
#  296096,
#  484468,
#  576,
#  10322,
#  84892,
#  123025,
#  1040,
#  544510,
#  19026,
#  1633,
#  4497,
#  374473,
#  220,
#  49026,
#  45269,
#  1417,
#  262,
#  8832,
#  1600,
#  14784,
#  1700,
#  2786,
#  1366,
#  334,
#  40662,
#  910,
#  419478,
#  653,
#  16306,
#  273248,
#  792,
#  288,
#  1939,
#  2433,
#  11421,
#  343,
#  993,
#  793,
#  227932,
#  12516,
#  13363,
#  40619,
#  13187,
#  1654,
#  396535,
#  11482,
#  10757,
#  820,
#  11658,
#  18079,
#  22,
#  96721,
#  205,
#  17483,
#  1879,
#  165,
#  672,
#  38251,
#  21734,
#  11356,
#  37247,
#  284427,
#  9343,
#  3767,
#  562,
#  166428,
#  10315,
#  313297,
#  503919,
#  4593,
#  83666,
#  68,
#  9475,
#  9806,
#  10331,
#  277216,
#  11299,
#  364137,
#  11040,
#  11327,
#  17057,
#  2062,
#  565310,
#  8073,
#  111083,
#  11113,
#  4024,
#  5528,
#  82702,
#  99,
#  158,
#  180299,
#  100402,
#  54186,
#  242582,
#  13413,
#  286217,
#  162,
#  200481,
#  41411,
#  9081,
#  1592,
#  221,
#  531,
#  11657,
#  49992,
#  8342,
#  12429,
#  26280,
#  11046,
#  3529,
#  15121,
#  5910,
#  767,
#  2493,
#  483184,
#  24428,
#  14756,
#  551332,
#  55,
#  1607,
#  1587,
#  272,
#  675,
#  306819,
#  283995,
#  468284,
#  976,
#  207703,
#  4995,
#  900,
#  3009,
#  375572,
#  11190,
#  64,
#  9552,
#  3133,
#  642,
#  244,
#  11610,
#  22683,
#  15137,
#  4909,
#  451480,
#  16642,
#  37719,
#  2013,
#  11016,
#  21575,
#  1632,
#  347201,
#  9377,
#  5165,
#  9023,
#  50531,
#  746,
#  10161,
#  9444,
#  9394,
#  4291,
#  4960,
#  643,
#  940,
#  323272,
#  773,
#  592,
#  11782,
#  2009,
#  648,
#  1567,
#  74879,
#  51608,
#  2000,
#  824,
#  514754,
#  522518,
#  489999,
#  1786,
#  17431,
#  10229,
#  11562,
#  11321,
#  10778,
#  4481,
#  9040,
#  16619,
#  5708,
#  6844,
#  8358,
#  871,
#  578,
#  167581,
#  638,
#  11031,
#  3001,
#  5143,
#  37769,
#  812,
#  451657,
#  177945,
#  309809,
#  14257,
#  222935,
#  413594,
#  12169,
#  4347,
#  337703,
#  9289,
#  339,
#  7500,
#  283587,
#  11167,
#  489418,
#  18333,
#  333339,
#  433,
#  3558,
#  71859,
#  14836,
#  71,
#  808,
#  10637,
#  375262,
#  574,
#  31417,
#  44214,
#  72478,
#  877,
#  14813,
#  1726,
#  9693,
#  246741,
#  36685,
#  440298,
#  985,
#  966,
#  586940,
#  137113,
#  7735,
#  907,
#  212,
#  308369,
#  439584,
#  244267,
#  765,
#  11906,
#  109424,
#  2649,
#  1904,
#  475,
#  57158,
#  183011,
#  1913,
#  1933,
#  1051,
#  6620,
#  27327,
#  342470,
#  264660,
#  63,
#  1902,
#  293660,
#  10907,
#  487558,
#  12498,
#  379,
#  109,
#  13060,
#  11178,
#  176241,
#  967,
#  16234,
#  269258,
#  315846,
#  11474,
#  565179,
#  319,
#  688,
#  175,
#  28874,
#  489930,
#  491418,
#  625,
#  11159,
#  451915,
#  11171,
#  11030,
#  4982,
#  83389,
#  1712,
#  63311,
#  529216,
#  649,
#  38757,
#  16958,
#  630,
#  3116,
#  277834,
#  284293,
#  51739,
#  983,
#  429617,
#  301528,
#  3580,
#  1554,
#  64690,
#  626,
#  13930,
#  11344,
#  5967,
#  284053,
#  244063,
#  377273,
#  15472,
#  457601,
#  19101,
#  229,
#  211954,
#  382614,
#  414425,
#  4174,
#  1023,
#  10747,
#  11481,
#  14282,
#  37181,
#  13466,
#  389015,
#  198375,
#  434616,
#  499631,
#  21450,
#  747,
#  15097,
#  432616,
#  440596,
#  863,
#  218,
#  11798,
#  419430,
#  8333,
#  782,
#  14645,
#  85350,
#  22584,
#  948,
#  9912,
#  984,
#  923,
#  11829,
#  137,
#  4553,
#  9549,
#  9340,
#  22881,
#  10683,
#  211387,
#  260513,
#  9366,
#  127585,
#  14919,
#  11704,
#  10549,
#  346648,
#  79,
#  7452,
#  186,
#  364433,
#  14092,
#  11471,
#  13310,
#  303483,
#  75629,
#  338,
#  3109,
#  12102,
#  4550,
#  3035,
#  1245,
#  15371,
#  11349,
#  571,
#  4638,
#  819,
#  37903,
#  251516,
#  1360,
#  10435,
#  265180,
#  431937,
#  387426,
#  228205,
#  380225,
#  587301,
#  383498,
#  4951,
#  59436,
#  244088,
#  13002,
#  10787,
#  8440,
#  1541,
#  6404,
#  1954,
#  11362,
#  519010,
#  363,
#  16372,
#  332562,
#  10110,
#  406385,
#  38396,
#  10784,
#  13446,
#  11969,
#  348678,
#  921,
#  290,
#  10734,
#  250219,
#  1407,
#  226,
#  3063,
#  11202,
#  334541,
#  4922,
#  1052,
#  902,
#  4203,
#  1372,
#  1883,
#  74308,
#  2056,
#  11688,
#  8740,
#  783,
#  532,
#  12163,
#  522,
#  404378,
#  407445,
#  10911,
#  329865,
#  616,
#  8321,
#  601,
#  138843,
#  828,
#  19067,
#  69,
#  376290,
#  650,
#  481432,
#  11901,
#  15764,
#  6916,
#  10950,
#  9665,
#  9385,
#  11549,
#  3085,
#  433247,
#  ...]

# %%
len(all_ids)
# Out:
# 6950
